# %% [markdown]
# # Data Acquisition
#
# The image dataset used in this project was obtained from [MushroomObserver](https://mushroomobserver.org/articles/20), a website dedicated to helping people identify mushrooms. They provide access to more than 370,000 community-annotated images with reasonable certainty levels. High-quality labeled data is crucial for machine learning models, as noisy labels can significantly reduce model performance.
#
# ## Download Dataset Catalogue
#
# Before processing the image data, we need to download the dataset catalogue from Google Sheets to get a comprehensive overview of available data. The catalogue contains image URLs, species names, and metadata from mushroom observations collected by the community.
#
# This step establishes the foundation for our dataset by providing a complete inventory of available images and their associated metadata.
#
# ### Output files
#
# - `mo_catalogue.tsv`: Contains image URLs and species names

# %%
import os

import pandas as pd

from utils.dataset_acquisition import download_google_sheets_tsv

GOOGLE_SHEETS_URL = "https://docs.google.com/spreadsheets/d/1aQSmLlthx99pCt_IS6aHyhZdn_hUiv3EBLbf4h3Zg7s/edit?usp=sharing"
TSV_OUTPUT_PATH = os.path.join("data", "mo_catalogue.tsv")

# Download the dataset if it doesn't exist
if not os.path.exists(TSV_OUTPUT_PATH):
    print("TSV file not found locally. Downloading from Google Sheets...")
    download_google_sheets_tsv(GOOGLE_SHEETS_URL, TSV_OUTPUT_PATH)

else:
    print("TSV file already exists: " + TSV_OUTPUT_PATH)

# Show basic info about existing file
file_size = os.path.getsize(TSV_OUTPUT_PATH)
df = pd.read_csv(TSV_OUTPUT_PATH, sep="\t")
print(f"Dataset contains {len(df):,} rows and {len(df.columns)} columns")
# Out:
# TSV file already exists: data/mo_catalogue.tsv
# Dataset contains 370,110 rows and 5 columns

# %% [markdown]
# ## Explore Dataset Catalogue
#
# Here we analyze the distribution of images across different species to identify which species have sufficient representation for neural network training. This exploration helps us understand the dataset composition and select species with adequate sample sizes.
#
# A minimum threshold is applied to filter species with insufficient data, ensuring we work with species that have enough examples for reliable model training and evaluation.
#
# ### Output files
#
# - `species_image_count_<threshold>.csv`: Contains species names and their corresponding image counts above the specified threshold

# %%
import os

import pandas as pd

from utils.dataset_acquisition import count_species

TSV_OUTPUT_PATH = os.path.join("data", "mo_catalogue.tsv")
data_catalogue_df = pd.read_csv(TSV_OUTPUT_PATH, sep="\t")
count_species(data_catalogue_df, 250)
# Out:
# 2025-07-18 09:23:34,150 - INFO - Processing species data...
# 2025-07-18 09:23:34,165 - INFO - Image list contains 10194 unique names
# 2025-07-18 09:23:34,167 - INFO - Image list contains 10193 unique species
# 2025-07-18 09:23:34,168 - INFO - Image list contains 287 unique species with more than 250 images
# 2025-07-18 09:23:34,169 - INFO - CSV file saved with name and counts: data/species_image_count_250.csv
# 2025-07-18 09:23:34,169 - INFO - Species with ≥250 images:
# 2025-07-18 09:23:34,170 - INFO -   - Trametes versicolor: 2018 images
# 2025-07-18 09:23:34,170 - INFO -   - Psilocybe pelliculosa: 1911 images
# 2025-07-18 09:23:34,170 - INFO -   - Psilocybe cyanescens: 1576 images
# 2025-07-18 09:23:34,171 - INFO -   - Ganoderma oregonense: 1544 images
# 2025-07-18 09:23:34,171 - INFO -   - Schizophyllum commune: 1395 images
# 2025-07-18 09:23:34,171 - INFO -   - Psilocybe ovoideocystidiata: 1353 images
# 2025-07-18 09:23:34,172 - INFO -   - Psilocybe zapotecorum: 1337 images
# 2025-07-18 09:23:34,172 - INFO -   - Galerina marginata: 1272 images
# 2025-07-18 09:23:34,172 - INFO -   - Amanita muscaria var. guessowii: 1146 images
# 2025-07-18 09:23:34,172 - INFO -   - Coprinus comatus: 1144 images
# 2025-07-18 09:23:34,173 - INFO -   - Phaeolus schweinitzii: 1077 images
# 2025-07-18 09:23:34,173 - INFO -   - Hypomyces lactifluorum: 1074 images
# 2025-07-18 09:23:34,173 - INFO -   - Pleurotus ostreatus: 1062 images
# 2025-07-18 09:23:34,174 - INFO -   - Amanita muscaria subsp. flavivolvata: 1056 images
# 2025-07-18 09:23:34,174 - INFO -   - Amanita phalloides: 1027 images
# 2025-07-18 09:23:34,174 - INFO -   - Psilocybe cubensis: 1007 images
# 2025-07-18 09:23:34,175 - INFO -   - Mycena haematopus: 968 images
# 2025-07-18 09:23:34,175 - INFO -   - Laetiporus sulphureus: 964 images
# 2025-07-18 09:23:34,175 - INFO -   - Trichaptum biforme: 941 images
# 2025-07-18 09:23:34,175 - INFO -   - Ganoderma applanatum: 939 images
# 2025-07-18 09:23:34,176 - INFO -   - Psilocybe caerulescens: 922 images
# 2025-07-18 09:23:34,177 - INFO -   - Hypholoma fasciculare: 892 images
# 2025-07-18 09:23:34,177 - INFO -   - Panellus stipticus: 857 images
# 2025-07-18 09:23:34,177 - INFO -   - Phyllotopsis nidulans: 815 images
# 2025-07-18 09:23:34,178 - INFO -   - Lycoperdon perlatum: 812 images
# 2025-07-18 09:23:34,179 - INFO -   - Cerioporus squamosus: 810 images
# 2025-07-18 09:23:34,179 - INFO -   - Mycena leaiana: 800 images
# 2025-07-18 09:23:34,180 - INFO -   - Lepista nuda: 796 images
# 2025-07-18 09:23:34,181 - INFO -   - Hypholoma lateritium: 774 images
# 2025-07-18 09:23:34,181 - INFO -   - Chlorophyllum molybdites: 767 images
# 2025-07-18 09:23:34,181 - INFO -   - Flammulina velutipes: 766 images
# 2025-07-18 09:23:34,181 - INFO -   - Tapinella atrotomentosa: 759 images
# 2025-07-18 09:23:34,182 - INFO -   - Cantharellus formosus: 740 images
# 2025-07-18 09:23:34,182 - INFO -   - Armillaria mellea: 733 images
# 2025-07-18 09:23:34,183 - INFO -   - Gliophorus psittacinus: 730 images
# 2025-07-18 09:23:34,183 - INFO -   - Suillus spraguei: 721 images
# 2025-07-18 09:23:34,184 - INFO -   - Psilocybe allenii: 717 images
# 2025-07-18 09:23:34,184 - INFO -   - Ischnoderma resinosum: 703 images
# 2025-07-18 09:23:34,184 - INFO -   - Morchella importuna: 701 images
# 2025-07-18 09:23:34,185 - INFO -   - Phlebia tremellosa: 692 images
# 2025-07-18 09:23:34,185 - INFO -   - Trametes gibbosa: 688 images
# 2025-07-18 09:23:34,185 - INFO -   - Entoloma abortivum: 676 images
# 2025-07-18 09:23:34,186 - INFO -   - Amanita brunnescens: 658 images
# 2025-07-18 09:23:34,186 - INFO -   - Stropharia rugosoannulata: 644 images
# 2025-07-18 09:23:34,186 - INFO -   - Pleurotus pulmonarius: 634 images
# 2025-07-18 09:23:34,187 - INFO -   - Retiboletus ornatipes: 629 images
# 2025-07-18 09:23:34,187 - INFO -   - Megacollybia rodmanii: 623 images
# 2025-07-18 09:23:34,188 - INFO -   - Lycogala epidendrum: 618 images
# 2025-07-18 09:23:34,188 - INFO -   - Leratiomyces ceres: 616 images
# 2025-07-18 09:23:34,188 - INFO -   - Artomyces pyxidatus: 613 images
# 2025-07-18 09:23:34,188 - INFO -   - Sarcomyxa serotina: 611 images
# 2025-07-18 09:23:34,189 - INFO -   - Tylopilus rubrobrunneus: 611 images
# 2025-07-18 09:23:34,189 - INFO -   - Tricholoma murrillianum: 609 images
# 2025-07-18 09:23:34,189 - INFO -   - Lactarius indigo: 608 images
# 2025-07-18 09:23:34,190 - INFO -   - Suillus americanus: 608 images
# 2025-07-18 09:23:34,190 - INFO -   - Bolbitius titubans: 607 images
# 2025-07-18 09:23:34,190 - INFO -   - Lacrymaria lacrymabunda: 601 images
# 2025-07-18 09:23:34,190 - INFO -   - Tylopilus felleus: 601 images
# 2025-07-18 09:23:34,191 - INFO -   - Ganoderma tsugae: 594 images
# 2025-07-18 09:23:34,191 - INFO -   - Boletus edulis: 593 images
# 2025-07-18 09:23:34,191 - INFO -   - Boletus edulis var. grandedulis: 590 images
# 2025-07-18 09:23:34,192 - INFO -   - Omphalotus illudens: 590 images
# 2025-07-18 09:23:34,192 - INFO -   - Grifola frondosa: 588 images
# 2025-07-18 09:23:34,192 - INFO -   - Agaricus augustus: 584 images
# 2025-07-18 09:23:34,192 - INFO -   - Pluteus cervinus: 576 images
# 2025-07-18 09:23:34,193 - INFO -   - Stropharia ambigua: 570 images
# 2025-07-18 09:23:34,193 - INFO -   - Pseudohydnum gelatinosum: 569 images
# 2025-07-18 09:23:34,193 - INFO -   - Daedaleopsis confragosa: 566 images
# 2025-07-18 09:23:34,194 - INFO -   - Fuligo septica: 565 images
# 2025-07-18 09:23:34,194 - INFO -   - Trametes betulina: 564 images
# 2025-07-18 09:23:34,194 - INFO -   - Gloeophyllum sepiarium: 564 images
# 2025-07-18 09:23:34,195 - INFO -   - Psilocybe caerulipes: 546 images
# 2025-07-18 09:23:34,195 - INFO -   - Laccaria ochropurpurea: 543 images
# 2025-07-18 09:23:34,195 - INFO -   - Lactarius rubidus: 541 images
# 2025-07-18 09:23:34,196 - INFO -   - Coprinellus micaceus: 538 images
# 2025-07-18 09:23:34,196 - INFO -   - Clitocybe nuda: 532 images
# 2025-07-18 09:23:34,197 - INFO -   - Suillus weaverae: 531 images
# 2025-07-18 09:23:34,197 - INFO -   - Hypholoma capnoides: 521 images
# 2025-07-18 09:23:34,198 - INFO -   - Amanita augusta: 512 images
# 2025-07-18 09:23:34,199 - INFO -   - Cryptoporus volvatus: 512 images
# 2025-07-18 09:23:34,199 - INFO -   - Psilocybe neoxalapensis: 510 images
# 2025-07-18 09:23:34,199 - INFO -   - Amanita flavoconia: 509 images
# 2025-07-18 09:23:34,200 - INFO -   - Rhizomarasmius pyrrhocephalus: 509 images
# 2025-07-18 09:23:34,200 - INFO -   - Agrocybe pediades: 508 images
# 2025-07-18 09:23:34,200 - INFO -   - Gloeoporus dichrous: 494 images
# 2025-07-18 09:23:34,201 - INFO -   - Tubaria furfuracea: 492 images
# 2025-07-18 09:23:34,201 - INFO -   - Fuscoporia gilva: 486 images
# 2025-07-18 09:23:34,201 - INFO -   - Cantharellus cinnabarinus: 486 images
# 2025-07-18 09:23:34,202 - INFO -   - Ceratiomyxa fruticulosa: 484 images
# 2025-07-18 09:23:34,202 - INFO -   - Candolleomyces candolleanus: 482 images
# 2025-07-18 09:23:34,202 - INFO -   - Leucoagaricus leucothites: 479 images
# 2025-07-18 09:23:34,202 - INFO -   - Baorangia bicolor: 478 images
# 2025-07-18 09:23:34,203 - INFO -   - Psilocybe muliercula: 477 images
# 2025-07-18 09:23:34,203 - INFO -   - Scleroderma citrinum: 477 images
# 2025-07-18 09:23:34,204 - INFO -   - Laetiporus cincinnatus: 475 images
# 2025-07-18 09:23:34,204 - INFO -   - Psilocybe semilanceata: 473 images
# 2025-07-18 09:23:34,204 - INFO -   - Fomitopsis mounceae: 472 images
# 2025-07-18 09:23:34,204 - INFO -   - Panaeolus foenisecii: 471 images
# 2025-07-18 09:23:34,205 - INFO -   - Gymnopus dryophilus: 463 images
# 2025-07-18 09:23:34,214 - INFO -   - Russula variata: 462 images
# 2025-07-18 09:23:34,216 - INFO -   - Suillus luteus: 459 images
# 2025-07-18 09:23:34,216 - INFO -   - Amanita velosa: 458 images
# 2025-07-18 09:23:34,218 - INFO -   - Lactifluus volemus: 457 images
# 2025-07-18 09:23:34,220 - INFO -   - Amanita muscaria: 457 images
# 2025-07-18 09:23:34,226 - INFO -   - Leotia lubrica: 453 images
# 2025-07-18 09:23:34,228 - INFO -   - Amanita flavorubens: 452 images
# 2025-07-18 09:23:34,229 - INFO -   - Lycoperdon pyriforme: 452 images
# 2025-07-18 09:23:34,230 - INFO -   - Agaricus xanthodermus: 451 images
# 2025-07-18 09:23:34,231 - INFO -   - Russula compacta: 447 images
# 2025-07-18 09:23:34,236 - INFO -   - Psilocybe azurescens: 447 images
# 2025-07-18 09:23:34,238 - INFO -   - Arrhenia chlorocyanea: 446 images
# 2025-07-18 09:23:34,240 - INFO -   - Hericium erinaceus: 438 images
# 2025-07-18 09:23:34,241 - INFO -   - Laccaria amethysteo-occidentalis: 438 images
# 2025-07-18 09:23:34,241 - INFO -   - Xylobolus frustulatus: 437 images
# 2025-07-18 09:23:34,241 - INFO -   - Laricifomes officinalis: 436 images
# 2025-07-18 09:23:34,242 - INFO -   - Amanita bisporigera: 434 images
# 2025-07-18 09:23:34,243 - INFO -   - Paxillus involutus: 432 images
# 2025-07-18 09:23:34,243 - INFO -   - Picipes badius: 428 images
# 2025-07-18 09:23:34,247 - INFO -   - Bjerkandera adusta: 424 images
# 2025-07-18 09:23:34,248 - INFO -   - Craterellus fallax: 421 images
# 2025-07-18 09:23:34,249 - INFO -   - Laccaria laccata: 421 images
# 2025-07-18 09:23:34,249 - INFO -   - Coprinopsis lagopus: 419 images
# 2025-07-18 09:23:34,250 - INFO -   - Boletus rex-veris: 411 images
# 2025-07-18 09:23:34,251 - INFO -   - Amanita persicina: 410 images
# 2025-07-18 09:23:34,252 - INFO -   - Panaeolus cinctulus: 409 images
# 2025-07-18 09:23:34,254 - INFO -   - Suillus caerulescens: 408 images
# 2025-07-18 09:23:34,255 - INFO -   - Hygrocybe cantharellus: 405 images
# 2025-07-18 09:23:34,255 - INFO -   - Trametes hirsuta: 402 images
# 2025-07-18 09:23:34,255 - INFO -   - Tricholomopsis rutilans: 401 images
# 2025-07-18 09:23:34,256 - INFO -   - Volvopluteus gloiocephalus: 399 images
# 2025-07-18 09:23:34,256 - INFO -   - Pluteus petasatus: 398 images
# 2025-07-18 09:23:34,256 - INFO -   - Stereum ostrea: 397 images
# 2025-07-18 09:23:34,256 - INFO -   - Hygrophoropsis aurantiaca: 396 images
# 2025-07-18 09:23:34,257 - INFO -   - Aleuria aurantia: 396 images
# 2025-07-18 09:23:34,257 - INFO -   - Hygrocybe flavescens: 391 images
# 2025-07-18 09:23:34,257 - INFO -   - Boletinellus merulioides: 390 images
# 2025-07-18 09:23:34,257 - INFO -   - Armillaria tabescens: 388 images
# 2025-07-18 09:23:34,258 - INFO -   - Bondarzewia berkeleyi: 387 images
# 2025-07-18 09:23:34,258 - INFO -   - Lactarius vinaceorufescens: 386 images
# 2025-07-18 09:23:34,258 - INFO -   - Retiboletus griseus: 385 images
# 2025-07-18 09:23:34,258 - INFO -   - Gyromitra esculenta: 385 images
# 2025-07-18 09:23:34,258 - INFO -   - Neoboletus chamaeleon: 384 images
# 2025-07-18 09:23:34,259 - INFO -   - Cantharellus subalbidus: 383 images
# 2025-07-18 09:23:34,259 - INFO -   - Leucoagaricus americanus: 378 images
# 2025-07-18 09:23:34,259 - INFO -   - Amanita rooseveltensis: 376 images
# 2025-07-18 09:23:34,259 - INFO -   - Panaeolus papilionaceus: 376 images
# 2025-07-18 09:23:34,260 - INFO -   - Marasmius oreades: 373 images
# 2025-07-18 09:23:34,260 - INFO -   - Cortinarius caperatus: 372 images
# 2025-07-18 09:23:34,260 - INFO -   - Auriscalpium vulgare: 370 images
# 2025-07-18 09:23:34,260 - INFO -   - Armillaria gallica: 369 images
# 2025-07-18 09:23:34,261 - INFO -   - Kretzschmaria deusta: 368 images
# 2025-07-18 09:23:34,263 - INFO -   - Stereum complicatum: 367 images
# 2025-07-18 09:23:34,273 - INFO -   - Sarcoscypha occidentalis: 364 images
# 2025-07-18 09:23:34,274 - INFO -   - Psilocybe mexicana: 361 images
# 2025-07-18 09:23:34,274 - INFO -   - Boletus separans: 359 images
# 2025-07-18 09:23:34,274 - INFO -   - Galiella rufa: 358 images
# 2025-07-18 09:23:34,275 - INFO -   - Fistulina hepatica: 357 images
# 2025-07-18 09:23:34,275 - INFO -   - Agrocybe praecox: 357 images
# 2025-07-18 09:23:34,275 - INFO -   - Daedalea quercina: 355 images
# 2025-07-18 09:23:34,276 - INFO -   - Dacrymyces chrysospermus: 353 images
# 2025-07-18 09:23:34,276 - INFO -   - Omphalotus olivascens: 351 images
# 2025-07-18 09:23:34,276 - INFO -   - Oudemansiella furfuracea: 351 images
# 2025-07-18 09:23:34,277 - INFO -   - Hypomyces chrysospermus: 349 images
# 2025-07-18 09:23:34,277 - INFO -   - Lactifluus hygrophoroides: 348 images
# 2025-07-18 09:23:34,278 - INFO -   - Lanmaoa pallidorosea: 347 images
# 2025-07-18 09:23:34,278 - INFO -   - Irpex lacteus: 346 images
# 2025-07-18 09:23:34,278 - INFO -   - Meripilus sumstinei: 346 images
# 2025-07-18 09:23:34,278 - INFO -   - Gymnopilus luteus: 344 images
# 2025-07-18 09:23:34,279 - INFO -   - Fomitopsis betulina: 344 images
# 2025-07-18 09:23:34,281 - INFO -   - Psilocybe stuntzii: 344 images
# 2025-07-18 09:23:34,282 - INFO -   - Truncospora ohiensis: 343 images
# 2025-07-18 09:23:34,282 - INFO -   - Marasmius rotula: 343 images
# 2025-07-18 09:23:34,283 - INFO -   - Chlorophyllum brunneum: 341 images
# 2025-07-18 09:23:34,283 - INFO -   - Coprinellus disseminatus: 338 images
# 2025-07-18 09:23:34,283 - INFO -   - Panus conchatus: 338 images
# 2025-07-18 09:23:34,283 - INFO -   - Entoloma murrayi: 337 images
# 2025-07-18 09:23:34,284 - INFO -   - Neofavolus alveolaris: 334 images
# 2025-07-18 09:23:34,284 - INFO -   - Tylopilus plumbeoviolaceus: 333 images
# 2025-07-18 09:23:34,284 - INFO -   - Crucibulum laeve: 333 images
# 2025-07-18 09:23:34,285 - INFO -   - Hericium coralloides: 331 images
# 2025-07-18 09:23:34,285 - INFO -   - Asterophora lycoperdoides: 330 images
# 2025-07-18 09:23:34,285 - INFO -   - Cantharellus californicus: 330 images
# 2025-07-18 09:23:34,285 - INFO -   - Cortinarius violaceus: 330 images
# 2025-07-18 09:23:34,286 - INFO -   - Xanthoconium affine: 330 images
# 2025-07-18 09:23:34,286 - INFO -   - Pycnoporellus fulgens: 329 images
# 2025-07-18 09:23:34,287 - INFO -   - Xerocomellus diffractus: 328 images
# 2025-07-18 09:23:34,287 - INFO -   - Cyathus striatus: 326 images
# 2025-07-18 09:23:34,287 - INFO -   - Amanita novinupta: 326 images
# 2025-07-18 09:23:34,288 - INFO -   - Psathyrella piluliformis: 326 images
# 2025-07-18 09:23:34,288 - INFO -   - Suillellus amygdalinus: 325 images
# 2025-07-18 09:23:34,288 - INFO -   - Scleroderma areolatum: 324 images
# 2025-07-18 09:23:34,289 - INFO -   - Abortiporus biennis: 324 images
# 2025-07-18 09:23:34,289 - INFO -   - Ganoderma sessile: 323 images
# 2025-07-18 09:23:34,289 - INFO -   - Rickenella fibula: 318 images
# 2025-07-18 09:23:34,289 - INFO -   - Trametes conchifer: 316 images
# 2025-07-18 09:23:34,290 - INFO -   - Entoloma quadratum: 315 images
# 2025-07-18 09:23:34,290 - INFO -   - Rhodocollybia butyracea: 313 images
# 2025-07-18 09:23:34,290 - INFO -   - Ganoderma curtisii: 312 images
# 2025-07-18 09:23:34,291 - INFO -   - Urnula craterium: 311 images
# 2025-07-18 09:23:34,291 - INFO -   - Trichaptum abietinum: 311 images
# 2025-07-18 09:23:34,291 - INFO -   - Hypomyces hyalinus: 308 images
# 2025-07-18 09:23:34,292 - INFO -   - Conocybe apala: 307 images
# 2025-07-18 09:23:34,292 - INFO -   - Sarcoscypha austriaca: 306 images
# 2025-07-18 09:23:34,292 - INFO -   - Suillus clintonianus: 304 images
# 2025-07-18 09:23:34,293 - INFO -   - Harrya chromapes: 302 images
# 2025-07-18 09:23:34,293 - INFO -   - Rhodocollybia maculata: 301 images
# 2025-07-18 09:23:34,293 - INFO -   - Chalciporus piperatus: 301 images
# 2025-07-18 09:23:34,293 - INFO -   - Stereum hirsutum: 300 images
# 2025-07-18 09:23:34,294 - INFO -   - Exidia crenata: 300 images
# 2025-07-18 09:23:34,294 - INFO -   - Leucopaxillus gentianeus: 300 images
# 2025-07-18 09:23:34,294 - INFO -   - Ampulloclitocybe clavipes: 299 images
# 2025-07-18 09:23:34,294 - INFO -   - Lactarius subpurpureus: 298 images
# 2025-07-18 09:23:34,295 - INFO -   - Psilocybe aztecorum: 297 images
# 2025-07-18 09:23:34,295 - INFO -   - Neoboletus subvelutipes: 296 images
# 2025-07-18 09:23:34,295 - INFO -   - Hydnellum spongiosipes: 296 images
# 2025-07-18 09:23:34,296 - INFO -   - Cerrena unicolor: 296 images
# 2025-07-18 09:23:34,297 - INFO -   - Morchella snyderi: 294 images
# 2025-07-18 09:23:34,298 - INFO -   - Leratiomyces percevalii: 293 images
# 2025-07-18 09:23:34,299 - INFO -   - Boletus subcaerulescens: 293 images
# 2025-07-18 09:23:34,299 - INFO -   - Aureoboletus innixus: 292 images
# 2025-07-18 09:23:34,300 - INFO -   - Gyroporus castaneus: 291 images
# 2025-07-18 09:23:34,300 - INFO -   - Tremella mesenterica: 291 images
# 2025-07-18 09:23:34,300 - INFO -   - Laetiporus gilbertsonii: 291 images
# 2025-07-18 09:23:34,301 - INFO -   - Cortinarius corrugatus: 290 images
# 2025-07-18 09:23:34,301 - INFO -   - Pulveroboletus ravenelii: 290 images
# 2025-07-18 09:23:34,301 - INFO -   - Hydnellum aurantiacum: 289 images
# 2025-07-18 09:23:34,302 - INFO -   - Hebeloma crustuliniforme: 288 images
# 2025-07-18 09:23:34,302 - INFO -   - Cuphophyllus pratensis: 286 images
# 2025-07-18 09:23:34,302 - INFO -   - Cantharellus lateritius: 285 images
# 2025-07-18 09:23:34,303 - INFO -   - Amanita farinosa: 285 images
# 2025-07-18 09:23:34,303 - INFO -   - Neolentinus lepideus: 283 images
# 2025-07-18 09:23:34,303 - INFO -   - Crepidotus applanatus: 283 images
# 2025-07-18 09:23:34,304 - INFO -   - Russula modesta: 283 images
# 2025-07-18 09:23:34,304 - INFO -   - Imleria pallida: 283 images
# 2025-07-18 09:23:34,304 - INFO -   - Polyporus umbellatus: 283 images
# 2025-07-18 09:23:34,304 - INFO -   - Radulomyces copelandii: 282 images
# 2025-07-18 09:23:34,305 - INFO -   - Morchella punctipes: 282 images
# 2025-07-18 09:23:34,305 - INFO -   - Chroogomphus tomentosus: 281 images
# 2025-07-18 09:23:34,306 - INFO -   - Chromosera loreleiae: 280 images
# 2025-07-18 09:23:34,307 - INFO -   - Cantharellula umbonata: 280 images
# 2025-07-18 09:23:34,307 - INFO -   - Clitocybe odora: 279 images
# 2025-07-18 09:23:34,307 - INFO -   - Coprinopsis variegata: 278 images
# 2025-07-18 09:23:34,308 - INFO -   - Hebeloma velutipes: 276 images
# 2025-07-18 09:23:34,308 - INFO -   - Laccaria amethystina: 275 images
# 2025-07-18 09:23:34,308 - INFO -   - Lanmaoa pseudosensibilis: 273 images
# 2025-07-18 09:23:34,309 - INFO -   - Lentinus brumalis: 273 images
# 2025-07-18 09:23:34,309 - INFO -   - Tyromyces chioneus: 272 images
# 2025-07-18 09:23:34,309 - INFO -   - Phylloporus arenicola: 272 images
# 2025-07-18 09:23:34,310 - INFO -   - Mycena subcaerulea: 272 images
# 2025-07-18 09:23:34,310 - INFO -   - Amanita calyptroderma: 272 images
# 2025-07-18 09:23:34,310 - INFO -   - Fomitopsis pinicola: 272 images
# 2025-07-18 09:23:34,311 - INFO -   - Panaeolus olivaceus: 270 images
# 2025-07-18 09:23:34,311 - INFO -   - Lactarius chrysorrheus: 269 images
# 2025-07-18 09:23:34,311 - INFO -   - Trametopsis cervina: 269 images
# 2025-07-18 09:23:34,311 - INFO -   - Crepidotus crocophyllus: 266 images
# 2025-07-18 09:23:34,312 - INFO -   - Hemileccinum subglabripes: 266 images
# 2025-07-18 09:23:34,312 - INFO -   - Mycena leptocephala: 264 images
# 2025-07-18 09:23:34,312 - INFO -   - Cortinarius iodes: 264 images
# 2025-07-18 09:23:34,313 - INFO -   - Ganoderma lobatum: 264 images
# 2025-07-18 09:23:34,314 - INFO -   - Mycena pura: 264 images
# 2025-07-18 09:23:34,315 - INFO -   - Clavulina coralloides: 263 images
# 2025-07-18 09:23:34,316 - INFO -   - Sutorius eximius: 262 images
# 2025-07-18 09:23:34,316 - INFO -   - Amanita ocreata: 262 images
# 2025-07-18 09:23:34,316 - INFO -   - Tetrapyrgos nigripes: 262 images
# 2025-07-18 09:23:34,317 - INFO -   - Psilocybe niveotropicalis: 262 images
# 2025-07-18 09:23:34,317 - INFO -   - Suillus lakei: 261 images
# 2025-07-18 09:23:34,318 - INFO -   - Gliophorus laetus: 260 images
# 2025-07-18 09:23:34,318 - INFO -   - Tricholomopsis decora: 259 images
# 2025-07-18 09:23:34,319 - INFO -   - Kuehneromyces marginellus: 259 images
# 2025-07-18 09:23:34,319 - INFO -   - Lichenomphalia umbellifera: 258 images
# 2025-07-18 09:23:34,319 - INFO -   - Pholiota squarrosoides: 258 images
# 2025-07-18 09:23:34,327 - INFO -   - Echinoderma asperum: 257 images
# 2025-07-18 09:23:34,331 - INFO -   - Crepidotus mollis: 257 images
# 2025-07-18 09:23:34,332 - INFO -   - Neoboletus varietatibus: 257 images
# 2025-07-18 09:23:34,333 - INFO -   - Morchella americana: 256 images
# 2025-07-18 09:23:34,333 - INFO -   - Tricholoma portentosum: 255 images
# 2025-07-18 09:23:34,335 - INFO -   - Panaeolus cyanescens: 255 images
# 2025-07-18 09:23:34,336 - INFO -   - Ductifera pululahuana: 253 images
# 2025-07-18 09:23:34,343 - INFO -   - Amanita pantherinoides: 252 images
# 2025-07-18 09:23:34,345 - INFO -   - Volvariella bombycina: 252 images
# 2025-07-18 09:23:34,347 - INFO -   - Geoglossum difforme: 251 images
# 2025-07-18 09:23:34,349 - INFO -   - Psilocybe yungensis: 251 images
# 2025-07-18 09:23:34,350 - INFO -   - Gymnopilus ventricosus: 251 images
# 2025-07-18 09:23:34,350 - INFO -   - Verpa bohemica: 251 images
# 2025-07-18 09:23:34,355 - INFO -   - Calocera cornea: 250 images
# 2025-07-18 09:23:34,360 - INFO -   - Phallus ravenelii: 250 images
# 2025-07-18 09:23:34,365 - INFO -   - Psilocybe subtropicalis: 250 images

# %% [markdown]
# ## Download Image Dataset
#
# After identifying species with sufficient representation, we proceed to download the actual images for the selected species. This process involves careful consideration of server resources and ethical web scraping practices.
#
# ## Ethical Data Scraping
#
# Data scraping can place significant burden on server infrastructures. MushroomObserver requests limiting the number of requests per minute, so I have implemented a comprehensive rate limiting system to strictly respect their guidelines and support this valuable non-profit resource.
#
# **Rate Limiting Implementation:**
#
# - **Maximum 20 requests per minute** (1 request every 3 seconds on average)
# - **Global rate limiting** across all concurrent operations
# - **Adaptive timing** based on server response times when available
# - **Automatic backoff** for rate limit violations (HTTP 429)
# - **Request queue management** to track requests over 60-second windows
# - **Respectful delays** between requests to minimize server load
#
# This enhanced rate limiting ensures we never exceed their capacity while maintaining efficient downloading, supporting the sustainability of this important community resource.
#
# ### Output files
#
# - `data/images/<species_name>/`: Directory structure containing downloaded images organized by species

# %%
from utils.dataset_acquisition import scrape_species_from_list

excluded_species_path = os.path.join("data", "excluded_species.csv")
species_list = ["Tylopilus felleus", "Imleria badia", "Boletus edulis"]

if scrape_species_from_list(data_catalogue_df, species_list):
    print("Data acquisition completed successfully.")
else:
    print("Data acquisition failed. Please check the logs for details.")
# Out:
# 2025-07-18 09:28:06,526 - INFO - Starting to scrape 3 species from provided list
# 2025-07-18 09:28:06,528 - INFO - Rate limiting: Maximum 20 requests per minute (3 seconds average)
# 2025-07-18 09:28:06,589 - INFO - Starting download for Tylopilus felleus: all 601 available images
# 2025-07-18 09:28:06,607 - INFO - Species Tylopilus felleus: All 601 images already downloaded
# 2025-07-18 09:28:06,622 - INFO - Starting download for Imleria badia: all 217 available images
# 2025-07-18 09:28:06,637 - INFO - Species Imleria badia: All 217 images already downloaded
# 2025-07-18 09:28:06,652 - INFO - Starting download for Boletus edulis: all 593 available images
# 2025-07-18 09:28:06,668 - INFO - Species Boletus edulis: All 593 images already downloaded
# Processing: Boletus edulis: 100%|██████████| 3/3 [00:00<00:00, 30.29species/s]
# 2025-07-18 09:28:06,669 - INFO - All species from list processed successfully.
# Data acquisition completed successfully.
